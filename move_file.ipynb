# %%
import os
import shutil

src_folder = "/home/isol/work/data/raw/vad_speech"
dst_folder = "/home/isol/work/data/train/noise_both_cut"

os.makedirs(dst_folder, exist_ok=True)

# %%
for file in os.listdir(src_folder):
    if not file.endswith(".wav"):
        continue
    src_path = os.path.join(src_folder, file)
    dst_path = os.path.join(dst_folder, file)
    shutil.move(src_path, dst_path)

# %%
len(os.listdir("/home/isol/work/data/raw/vad_silence"))
# Out:
# 0

# %%
len(os.listdir("/home/isol/work/data/raw/vad_speech"))
# Out:
# 0
